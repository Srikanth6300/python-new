# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikanth6300/python-new/blob/module-4/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as sk
import numpy as np
xpoints= np.array([0,10])
ypoints= np.array([0,350])
sk.plot(xpoints,ypoints)
sk.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1, 9])
ypoints = np.array([3, 12])
plt.plot(xpoints, ypoints, '*')
plt.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
xpoints= np.array(['a','b','c','d'])
ypoints= np.array([6,7,9,3])
sk.bar(xpoints,ypoints,color="red")
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 7, 10, 9])
sk.bar(x, y, width = 0.1)
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 7, 10, 9])
sk.barh(x, y)
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 9, 1, 12])
sk.barh(x, y, height = 0.1)
sk.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 10, 1, 9])
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
y = np.array([35, 25, 25, 15])
mylables=["sea water","river water","lake water","pond water"]
sk.pie(y,labels=mylables)
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
x = np.random.normal(150, 10, 290)
sk.hist(x)
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
x = np.random.normal(170, 10, 250)
sk.hist(x)
sk.show()

# %%
from ssl import SOCK_STREAM
import matplotlib.pyplot as sk
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,67,86,103,87,94,78,98,85,86])

sk.scatter(x, y,color="red")
SOCK_STREAM.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-77bd2dbea654> in <module>()
#       7
#       8 sk.scatter(x, y,color="red")
# ----> 9 SOCK_STREAM.show()
#
# AttributeError: 'SocketKind' object has no attribute 'show'

# %%
import matplotlib.pyplot as plt
import numpy as np
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colors)
plt.show()

# %%
import matplotlib.pyplot as sk
import numpy as np

y = np.array([5, 14, 1, 15])

sk.plot(y, marker = 'o')
sk.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 10, 1, 9])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([5, 8, 1, 9, 6, 7])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
y = np.array([5, 14, 1, 15,29,34,45])
sk.plot(y, marker = '*')
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
y = np.array([5, 14, 1, 15,29,34,45])
sk.plot(y, 'o:y')
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
y = np.array([5, 14, 1, 15,29,34,45])
sk.plot(y, marker = '*', ms=30)
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
y = np.array([5, 14, 1, 15,29,34,45])
sk.plot(y, marker = '*', ms=20, mec = 'r')
sk.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([9, 19, 1, 12])

plt.plot(ypoints, linewidth = '18')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([3, 8, 1, 13])
y2 = np.array([9, 2, 7, 19])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 240, 270, 280, 260, 300, 300, 330, 340])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 330, 340])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 9])
plt.subplot(1, 2, 1)
plt.plot(x,y)
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x,y)
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y,color='yellow')
plt.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["maths", "english", "Chemistry", "physics"]
myexplode = [0.2, 0.2, 0.2, 0.2]
sk.pie(y, labels = mylabels, explode = myexplode)
sk.show()

# %%
import matplotlib.pyplot as sk
import numpy as np
x= np.array([30, 25,25,20])
mylabels =["maths", "english", "chemistry", "physics"]
mycolors = ["red", "green", "orange", "yellow"]
myexpolde = [0.2, 0.2, 0.2, 0.2]
sk.pie(x, labels = mylabels,colors = mycolors, explode = myexplode )
sk.show()

# %%
import matplotlib.pyplot as sk 
plt.scatter( 0 , 0 , s = 10000 ) 
plt.xlim( -0.85 , 0.85 ) 
sk.ylim( -0.95 , 0.95 )  
sk.title( "Scatter plot of points Circle" ) 
sk.show()

# %%
import matplotlib.pyplot as sk
sk.scatter( 0 , 0 , s=10000 ,  facecolors='none', edgecolors='red' ) 
sk.xlim( -0.5 , 0.5 )
sk.ylim( -0.5 , 0.5 ) 
sk.show()
